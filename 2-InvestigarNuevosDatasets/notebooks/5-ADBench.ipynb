# %%
#librerias 
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import os 
import re 
from datetime import datetime

# %%
BASE_DATA_DIR="../data/"
data_dir=os.path.join(BASE_DATA_DIR,"ADBench_Classical")
list_files=os.listdir(data_dir)
train_dirs=[os.path.join(data_dir,i) for i in list_files]

# %%
n=15
a=np.load(train_dirs[n])
print(list_files[n])
print(a.files)
# Out:
# 4_breastw.npz
# ['X', 'y']

# %%
a["X"].shape
# Out:
# (683, 9)

# %%
plt.figure(figsize=(17,4))
plt.plot(a["X"][:,8])
for i in np.argwhere(a["y"]==1):
    plt.axvline(i,color="red",alpha=0.2)
